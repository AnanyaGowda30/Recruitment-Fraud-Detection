# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

from backend.cyber_features import extract_cyber_features

# %%
sample = """
Urgent Hiring!

ABC Pvt Ltd

Salary ₹15,00,000

Apply immediately

Send CV to hr@gmail.com

Visit https://abc.com
"""

result = extract_cyber_features(sample)

print(result)
# Out:
# {'has_email': 1, 'gmail_email': 1, 'has_url': 1, 'whatsapp': 0, 'phone': 0, 'registration_fee': 0, 'urgency_score': 3, 'immediate_joining': 0, 'freshers': 0, 'work_from_home': 0, 'salary_present': 1, 'high_salary': 0, 'company_score': 2}
